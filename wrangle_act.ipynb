# %% [markdown]
# # Project: Wrangling and Analyze Data

# %% [markdown]
# ## Data Gathering
# In the cell below, gather **all** three pieces of data for this project and load them in the notebook. **Note:** the methods required to gather each data are different.
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)

# %%
import pandas as pd
twitter_archive = pd.read_csv('twitter-archive-enhanced.csv')
twitter_archive
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %% [raw]
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
# uploading and reading the file from the provided link
import requests
predictions = requests.get('https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv')

with open("predictions", mode="wb") as file:
    file.write(predictions.content)

predictions = pd.read_csv('predictions', sep='\t')

# %% [markdown]
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)

# %%
#import tweepy
#consumer_key = ''
#consumer_secret = ''
#access_token = ''
#access_secret = ''

#auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#auth.set_access_token(access_token, access_secret)

#api = tweepy.API(auth)
#api

# %%
#get tweets using the twitter API
#empty dictionary called tweets
##tweets = []
#tweets that can't be found dictionary
# for loop that gets each tweet through its id
##unavailable_tweets = []
##for each_id in twitter_archive.tweet_id:   
    ##try:
        ##tweets.append(api.get_status(each_id))
        ##tweets.append(api.retweets.count()(each_id))
        ##tweets.append(api.likes.count()(each_id))
    ##except Exception as e:
        ##unavailable_tweets.append(each_id)

# %%
df = pd.read_json('tweet-json.txt', lines = True)
df
# Out:
#       contributors  coordinates          created_at display_text_range  \
# 0              NaN          NaN 2017-08-01 16:23:56            [0, 85]
# 1              NaN          NaN 2017-08-01 00:17:27           [0, 138]
# 2              NaN          NaN 2017-07-31 00:18:03           [0, 121]
# 3              NaN          NaN 2017-07-30 15:58:51            [0, 79]
# 4              NaN          NaN 2017-07-29 16:00:24           [0, 138]
# 5              NaN          NaN 2017-07-29 00:08:17           [0, 138]
# 6              NaN          NaN 2017-07-28 16:27:12           [0, 140]
# 7              NaN          NaN 2017-07-28 00:22:40           [0, 118]
# 8              NaN          NaN 2017-07-27 16:25:51           [0, 122]
# 9              NaN          NaN 2017-07-26 15:59:51           [0, 133]
# 10             NaN          NaN 2017-07-26 00:31:25           [0, 130]
# 11             NaN          NaN 2017-07-25 16:11:53           [0, 107]
# ...

# %%
#https://stackoverflow.com/questions/47612822/how-to-create-pandas-dataframe-from-twitter-search-api
    
#https://stackoverflow.com/questions/28384588/twitter-api-get-tweets-with-specific-id

# %% [markdown]
# ## Assessing Data
# In this section, detect and document at least **eight (8) quality issues and two (2) tidiness issue**. You must use **both** visual assessment
# programmatic assessement to assess the data.
#
# **Note:** pay attention to the following key points when you access the data.
#
# * You only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# * Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# * The fact that the rating numerators are greater than the denominators does not need to be cleaned. This [unique rating system](http://knowyourmeme.com/memes/theyre-good-dogs-brent) is a big part of the popularity of WeRateDogs.
# * You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.

# %% [markdown]
# #### The twitter archive file

# %%
#  creating a copy of our dataset
twitter_archive_clean = twitter_archive.copy()

# %%
# displaying the first five rows
twitter_archive_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
# getting a random sample of our dataset
twitter_archive_clean.sample(3)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 6     890971913173991426                    NaN                  NaN
# 2060  671182547775299584                    NaN                  NaN
# 1744  679158373988876288                    NaN                  NaN
#
#                       timestamp  \
# 6     2017-07-28 16:27:12 +0000
# 2060  2015-11-30 04:22:44 +0000
# 1744  2015-12-22 04:35:49 +0000
#
#                                                  source  \
# 6     <a href="http://twitter.com/download/iphone" r...
# 2060  <a href="http://twitter.com/download/iphone" r...
# 1744  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 6     Meet Jax. He enjoys ice cream so much he gets ...                  NaN
# 2060  This pup holds the secrets of the universe in ...                  NaN
# 1744  This is Rubio. He has too much skin. 11/10 htt...                  NaN
#
# ...

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
# searching for duplicates in the data
twitter_archive_clean[twitter_archive_clean.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
# searching for blank values in the data
twitter_archive_clean.isnull()
# Out:
#       tweet_id  in_reply_to_status_id  in_reply_to_user_id  timestamp  source  \
# 0        False                   True                 True      False   False
# 1        False                   True                 True      False   False
# 2        False                   True                 True      False   False
# 3        False                   True                 True      False   False
# 4        False                   True                 True      False   False
# 5        False                   True                 True      False   False
# 6        False                   True                 True      False   False
# 7        False                   True                 True      False   False
# 8        False                   True                 True      False   False
# 9        False                   True                 True      False   False
# 10       False                   True                 True      False   False
# ...

# %%
# getting descriptive statistics
twitter_archive.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %% [markdown]
# #### Image predictions file

# %%
predictions_clean = predictions.copy()

# %%
predictions_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
predictions_clean.sample(3)
# Out:
#                 tweet_id                                          jpg_url  \
# 2034  883838122936631299  https://pbs.twimg.com/media/DEQGFgAXUAAEvfi.jpg
# 1782  828770345708580865  https://pbs.twimg.com/media/C4BiOXOXAAAf6IS.jpg
# 1993  874012996292530176  https://pbs.twimg.com/media/DCEeLxjXsAAvNSM.jpg
#
#       img_num         p1   p1_conf  p1_dog                        p2  \
# 2034        1   Doberman  0.610946    True        miniature_pinscher
# 1782        1  seat_belt  0.765979   False  Chesapeake_Bay_retriever
# 1993        2   Cardigan  0.806674    True                  Pembroke
#
#        p2_conf  p2_dog       p3   p3_conf  p3_dog
# 2034  0.299603    True   kelpie  0.063020    True
# 1782  0.033899    True  polecat  0.027252   False
# 1993  0.116622    True   kelpie  0.049182    True

# %%
predictions_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
predictions_clean[predictions_clean.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []

# %%
predictions_clean.isnull()
# Out:
#       tweet_id  jpg_url  img_num     p1  p1_conf  p1_dog     p2  p2_conf  \
# 0        False    False    False  False    False   False  False    False
# 1        False    False    False  False    False   False  False    False
# 2        False    False    False  False    False   False  False    False
# 3        False    False    False  False    False   False  False    False
# 4        False    False    False  False    False   False  False    False
# 5        False    False    False  False    False   False  False    False
# 6        False    False    False  False    False   False  False    False
# 7        False    False    False  False    False   False  False    False
# 8        False    False    False  False    False   False  False    False
# 9        False    False    False  False    False   False  False    False
# 10       False    False    False  False    False   False  False    False
# 11       False    False    False  False    False   False  False    False
# ...

# %%
predictions_clean.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %% [markdown]
# #### Tweet json file

# %%
# creating a copy of our dataset
tweets_clean = df.copy()

# %%
tweets_clean.head()
# Out:
#    contributors  coordinates          created_at display_text_range  \
# 0           NaN          NaN 2017-08-01 16:23:56            [0, 85]
# 1           NaN          NaN 2017-08-01 00:17:27           [0, 138]
# 2           NaN          NaN 2017-07-31 00:18:03           [0, 121]
# 3           NaN          NaN 2017-07-30 15:58:51            [0, 79]
# 4           NaN          NaN 2017-07-29 16:00:24           [0, 138]
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [{'text': 'BarkWeek', 'indices': ...
#
#                                    extended_entities  favorite_count  \
# 0  {'media': [{'id': 892420639486877696, 'id_str'...           39467
# 1  {'media': [{'id': 892177413194625024, 'id_str'...           33819
# ...

# %%
tweets_clean.sample(3)
# Out:
#       contributors  coordinates          created_at display_text_range  \
# 1028           NaN          NaN 2016-06-22 01:50:58            [0, 99]
# 365            NaN          NaN 2017-02-07 03:04:22           [0, 140]
# 172            NaN          NaN 2017-04-30 00:02:42           [0, 113]
#
#                                                entities  \
# 1028  {'hashtags': [], 'symbols': [], 'user_mentions...
# 365   {'hashtags': [], 'symbols': [], 'user_mentions...
# 172   {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                       extended_entities  favorite_count  \
# 1028  {'media': [{'id': 745433859332898817, 'id_str'...            7824
# 365                                                 NaN               0
# 172   {'media': [{'id': 858471621065150464, 'id_str'...           22640
#
#       favorited                                          full_text  geo  \
# 1028      False  This is Lenox. She's in a wheelbarrow. Silly d...  NaN
# ...

# %%
tweets_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
# contributors                     0 non-null float64
# coordinates                      0 non-null float64
# created_at                       2354 non-null datetime64[ns]
# display_text_range               2354 non-null object
# entities                         2354 non-null object
# extended_entities                2073 non-null object
# favorite_count                   2354 non-null int64
# favorited                        2354 non-null bool
# full_text                        2354 non-null object
# geo                              0 non-null float64
# id                               2354 non-null int64
# id_str                           2354 non-null int64
# in_reply_to_screen_name          78 non-null object
# in_reply_to_status_id            78 non-null float64
# in_reply_to_status_id_str        78 non-null float64
# ...

# %%
tweets_clean.retweeted
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 2324    False
# 2325    False
# 2326    False
# 2327    False
# 2328    False
# 2329    False
# 2330    False
# 2331    False
# 2332    False
# 2333    False
# 2334    False
# 2335    False
# 2336    False
# 2337    False
# 2338    False
# 2339    False
# 2340    False
# 2341    False
# 2342    False
# 2343    False
# 2344    False
# 2345    False
# 2346    False
# 2347    False
# 2348    False
# 2349    False
# 2350    False
# 2351    False
# 2352    False
# 2353    False
# ...

# %%
# searching for blank values in our dataset
tweets_clean.isnull()
# Out:
#       contributors  coordinates  created_at  display_text_range  entities  \
# 0             True         True       False               False     False
# 1             True         True       False               False     False
# 2             True         True       False               False     False
# 3             True         True       False               False     False
# 4             True         True       False               False     False
# 5             True         True       False               False     False
# 6             True         True       False               False     False
# 7             True         True       False               False     False
# 8             True         True       False               False     False
# 9             True         True       False               False     False
# 10            True         True       False               False     False
# 11            True         True       False               False     False
# ...

# %%
# checking if our dataset contains retweets 
tweets_clean[tweets_clean['retweeted'] ==  True]
# Out:
# Empty DataFrame
# Columns: [contributors, coordinates, created_at, display_text_range, entities, extended_entities, favorite_count, favorited, full_text, geo, id, id_str, in_reply_to_screen_name, in_reply_to_status_id, in_reply_to_status_id_str, in_reply_to_user_id, in_reply_to_user_id_str, is_quote_status, lang, place, possibly_sensitive, possibly_sensitive_appealable, quoted_status, quoted_status_id, quoted_status_id_str, retweet_count, retweeted, retweeted_status, source, truncated, user]
# Index: []
#
# [0 rows x 31 columns]

# %%
# getting descriptive statistics for our dataset
tweets_clean.describe()
# Out:
#        contributors  coordinates  favorite_count  geo            id  \
# count           0.0          0.0     2354.000000  0.0  2.354000e+03
# mean            NaN          NaN     8080.968564  NaN  7.426978e+17
# std             NaN          NaN    11814.771334  NaN  6.852812e+16
# min             NaN          NaN        0.000000  NaN  6.660209e+17
# 25%             NaN          NaN     1415.000000  NaN  6.783975e+17
# 50%             NaN          NaN     3603.500000  NaN  7.194596e+17
# 75%             NaN          NaN    10122.250000  NaN  7.993058e+17
# max             NaN          NaN   132810.000000  NaN  8.924206e+17
#
#              id_str  in_reply_to_status_id  in_reply_to_status_id_str  \
# count  2.354000e+03           7.800000e+01               7.800000e+01
# mean   7.426978e+17           7.455079e+17               7.455079e+17
# std    6.852812e+16           7.582492e+16               7.582492e+16
# min    6.660209e+17           6.658147e+17               6.658147e+17
# ...

# %% [markdown]
# ### Quality issues
# 1. The rating numerator for index 2235 is 2 instead of 10 in the twitter-archive-enhanced file.
#
# 2. Incorrect data type for timestamp variable name in the twitter archive file. Incorrect data type for tweet_id in the twitter archive file. This would need to be changed to a category data type to enable better data wrangling. rating_numerator and rating_denominator should be changed to a float datatype.
#
# - We have some tweets that are not orihginal ratings for the dogs. We need to get rid of retweets in our dataset.
#
# 3. Missing variable values in the twitter archive dataset including:
#  - in_reply_to_status_id
#  - in_reply_to_user_id
#  - retweeted_status_id
#  - retweeted_status_user_id
#  - retweeted_status_timestamp
#  - expanded_urls
#
# 4. Missing variable values in the tweet-json dataset including:
#  - contributors
#  - coordinates
#  - extended_entities
#  - geo
#  - in_reply_to_screen_name
#  - in_reply_to_status_id
#  - in_reply_to_status_id_str
#  - in_reply_to_user_id
#  - in_reply_to_user_id_str
#  - place
#  - possibly_sensitive
#  - possibly_sensitive_appealable
#  - quoted_status
#  - quoted_status_id
#  - quoted_status_id_str
#  - retweeted_status
#
# - Getting rid of contributors, coordinates and geo columns in the tweet-json dataset as they are empty.
#
# 5. p1, p2, and p3 in the Image predictions dataset do not have consistent letter format to give the names of dogs i.e. some dog names have capitalised first letters while others do not.
#
# 6. There exist images in the image predictions dataset that are not dogs. We would need to get rid of these as we are only interested in images of dogs.

# %% [markdown]
# ### Tidiness issues
# 1. There is no need for 2 different datasets(tweet-json file and the twitter archive file). The two can be merged.
#
# 2. floofer, puppo, and doggo columns that denote the stage in which the dog is in are mutually exclusive except when a mistake occurs. They should therefore be in a single column.

# %% [markdown]
# ## Cleaning Data
# In this section, clean **all** of the issues you documented while assessing.
#
# **Note:** Make a copy of the original data before cleaning. Cleaning includes merging individual pieces of data according to the rules of [tidy data](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). The result should be a high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %%
# Make copies of original pieces of data
print("This has been done previously.")
# Out:
# This has been done previously.

# %% [markdown]
# ### Issue #1:

# %% [markdown]
# #### Define:
# The rating numerator for index 2235 is 2 instead of 10 in the twitter-archive-enhanced file.

# %%
twitter_archive_clean
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %% [markdown]
# #### Code

# %%
# changing the rating denominator to 10.
twitter_archive_clean['rating_denominator'].replace('2', '10', inplace= True)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.iloc[2235]
# Out:
# tweet_id                                                     668171859951755264
# in_reply_to_status_id                                                       NaN
# in_reply_to_user_id                                                         NaN
# timestamp                                             2015-11-21 20:59:20 +0000
# source                        <a href="http://twitter.com/download/iphone" r...
# text                          This is a Trans Siberian Kellogg named Alfonso...
# retweeted_status_id                                                         NaN
# retweeted_status_user_id                                                    NaN
# retweeted_status_timestamp                                                  NaN
# expanded_urls                 https://twitter.com/dog_rates/status/668171859...
# rating_numerator                                                              7
# rating_denominator                                                           10
# ...

# %% [markdown]
# ### Issue #2:

# %% [markdown]
# #### Define:
# Incorrect data type for timestamp variable name in the twitter archive file. Incorrect data type for tweet_id in the twitter archive file. This would need to be changed to a category data type to enable better data wrangling. Rating numerator and rating denominator columns should be floats.

# %%
twitter_archive_clean.timestamp
# Out:
# 0       2017-08-01 16:23:56 +0000
# 1       2017-08-01 00:17:27 +0000
# 2       2017-07-31 00:18:03 +0000
# 3       2017-07-30 15:58:51 +0000
# 4       2017-07-29 16:00:24 +0000
# 5       2017-07-29 00:08:17 +0000
# 6       2017-07-28 16:27:12 +0000
# 7       2017-07-28 00:22:40 +0000
# 8       2017-07-27 16:25:51 +0000
# 9       2017-07-26 15:59:51 +0000
# 10      2017-07-26 00:31:25 +0000
# 11      2017-07-25 16:11:53 +0000
# 12      2017-07-25 01:55:32 +0000
# 13      2017-07-25 00:10:02 +0000
# 14      2017-07-24 17:02:04 +0000
# 15      2017-07-24 00:19:32 +0000
# 16      2017-07-23 00:22:39 +0000
# 17      2017-07-22 16:56:37 +0000
# 18      2017-07-22 00:23:06 +0000
# 19      2017-07-21 01:02:36 +0000
# 20      2017-07-20 16:49:33 +0000
# 21      2017-07-19 16:06:48 +0000
# 22      2017-07-19 03:39:09 +0000
# 23      2017-07-19 00:47:34 +0000
# 24      2017-07-18 16:08:03 +0000
# 25      2017-07-18 00:07:08 +0000
# 26      2017-07-17 16:17:36 +0000
# ...

# %% [markdown]
# #### Code

# %%
twitter_archive_clean.timestamp = pd.to_datetime(twitter_archive_clean.timestamp)
twitter_archive_clean['tweet_id'] = twitter_archive_clean['tweet_id'].astype('category')
twitter_archive_clean['rating_numerator'] = twitter_archive_clean['rating_numerator'].astype('float')
twitter_archive_clean['rating_denominator'] = twitter_archive_clean['rating_denominator'].astype('float')

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null category
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null datetime64[ns]
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null float64
# rating_denominator            2356 non-null float64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
twitter_archive_clean['tweet_id'].dtype
# Out:
# CategoricalDtype(categories=[666020888022790149, 666029285002620928, 666033412701032449,
#                   666044226329800704, 666049248165822465, 666050758794694657,
#                   666051853826850816, 666055525042405380, 666057090499244032,
#                   666058600524156928,
#                   ...
#                   890240255349198849, 890609185150312448, 890729181411237888,
#                   890971913173991426, 891087950875897856, 891327558926688256,
#                   891689557279858688, 891815181378084864, 892177421306343426,
#                   892420643555336193],
#                  ordered=False)

# %% [markdown]
# ### #Issue 3

# %% [markdown]
# #### Define:
# Removing retweets from our dataset

# %% [markdown]
# #### Clean

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null category
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null datetime64[ns]
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null float64
# rating_denominator            2356 non-null float64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
twitter_archive_clean = twitter_archive_clean[twitter_archive_clean['retweeted_status_id'].isnull()]
twitter_archive_clean = twitter_archive_clean[twitter_archive_clean['retweeted_status_user_id'].isnull()]
twitter_archive_clean = twitter_archive_clean[twitter_archive_clean['retweeted_status_timestamp'].isnull()]

# %% [markdown]
# #### Test

# %%
twitter_archive_clean[(twitter_archive_clean['retweeted_status_id'].notnull()) | (twitter_archive_clean['retweeted_status_user_id'].notnull()) | (twitter_archive_clean['retweeted_status_timestamp'].notnull())]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# ### #Issue 4

# %% [markdown]
# #### Define:
# Missing variable values in the twitter archive dataset including:
#  - in_reply_to_status_id
#  - in_reply_to_user_id
#  - retweeted_status_id
#  - retweeted_status_user_id
#  - retweeted_status_timestamp
#  - expanded_urls

# %% [markdown]
# #### Clean

# %%
twitter_archive_clean['in_reply_to_status_id'].dropna(inplace = True)
twitter_archive_clean['in_reply_to_user_id'].dropna(inplace = True)
twitter_archive_clean['retweeted_status_id'].dropna(inplace = True)
twitter_archive_clean['retweeted_status_user_id'].dropna(inplace = True)
twitter_archive_clean['retweeted_status_timestamp'].dropna(inplace = True)
twitter_archive_clean['expanded_urls'].dropna(inplace = True)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2175 non-null category
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2175 non-null datetime64[ns]
# source                        2175 non-null object
# text                          2175 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 2117 non-null object
# rating_numerator              2175 non-null float64
# rating_denominator            2175 non-null float64
# name                          2175 non-null object
# doggo                         2175 non-null object
# floofer                       2175 non-null object
# pupper                        2175 non-null object
# ...

# %%
twitter_archive_clean['in_reply_to_status_id']
# Out:
# 30      8.862664e+17
# 55      8.816070e+17
# 64      8.795538e+17
# 113     8.707262e+17
# 148     8.634256e+17
# 149     6.671522e+17
# 179     8.571567e+17
# 184     8.558181e+17
# 186     8.562860e+17
# 188     8.558616e+17
# 189     8.558585e+17
# 218     8.503288e+17
# 228     8.482121e+17
# 234     8.476062e+17
# 251     7.590995e+17
# 274     8.406983e+17
# 290     8.381455e+17
# 291     8.380855e+17
# 313     8.352460e+17
# 342     8.320875e+17
# 346     8.319030e+17
# 387     8.265984e+17
# 409     8.233264e+17
# 427     8.211526e+17
# 498     8.131273e+17
# 513     8.116272e+17
# 565     7.331095e+17
# 570     8.018543e+17
# 576     8.008580e+17
# 611     7.971238e+17
#             ...
# 1479    6.935722e+17
# 1497    6.924173e+17
# 1501    6.920419e+17
# 1523    6.903413e+17
# 1598    6.860340e+17
# 1605    6.855479e+17
# 1618    6.849598e+17
# 1630    6.844811e+17
# 1634    6.842229e+17
# 1663    6.827884e+17
# 1689    6.813394e+17
# 1774    6.780211e+17
# ...

# %%
twitter_archive_clean['in_reply_to_user_id']
# Out:
# 30      2.281182e+09
# 55      4.738443e+07
# 64      3.105441e+09
# 113     1.648776e+07
# 148     7.759620e+07
# 149     4.196984e+09
# 179     1.806710e+08
# 184     4.196984e+09
# 186     2.792810e+08
# 188     1.943518e+08
# 189     1.361572e+07
# 218     2.195506e+07
# 228     4.196984e+09
# 234     4.196984e+09
# 251     4.196984e+09
# 274     8.405479e+17
# 290     2.195506e+07
# 291     2.894131e+09
# 313     2.625958e+07
# 342     3.058208e+07
# 346     2.068372e+07
# 387     4.196984e+09
# 409     1.582854e+09
# 427     1.132119e+08
# 498     4.196984e+09
# 513     4.196984e+09
# 565     4.196984e+09
# 570     1.185634e+07
# 576     2.918590e+08
# 611     2.916630e+07
#             ...
# 1479    1.198989e+09
# 1497    4.196984e+09
# 1501    4.196984e+09
# 1523    4.670367e+08
# 1598    4.196984e+09
# 1605    4.196984e+09
# 1618    4.196984e+09
# 1630    4.196984e+09
# 1634    4.196984e+09
# 1663    4.196984e+09
# 1689    4.196984e+09
# 1774    4.196984e+09
# ...

# %%
twitter_archive_clean['retweeted_status_id']
# Out:
# Series([], Name: retweeted_status_id, dtype: float64)

# %%
twitter_archive_clean['retweeted_status_user_id']
# Out:
# Series([], Name: retweeted_status_user_id, dtype: float64)

# %%
twitter_archive_clean['retweeted_status_timestamp']
# Out:
# Series([], Name: retweeted_status_timestamp, dtype: object)

# %%
twitter_archive_clean['expanded_urls']
# Out:
# 0       https://twitter.com/dog_rates/status/892420643...
# 1       https://twitter.com/dog_rates/status/892177421...
# 2       https://twitter.com/dog_rates/status/891815181...
# 3       https://twitter.com/dog_rates/status/891689557...
# 4       https://twitter.com/dog_rates/status/891327558...
# 5       https://twitter.com/dog_rates/status/891087950...
# 6       https://gofundme.com/ydvmve-surgery-for-jax,ht...
# 7       https://twitter.com/dog_rates/status/890729181...
# 8       https://twitter.com/dog_rates/status/890609185...
# 9       https://twitter.com/dog_rates/status/890240255...
# 10      https://twitter.com/dog_rates/status/890006608...
# 11      https://twitter.com/dog_rates/status/889880896...
# 12      https://twitter.com/dog_rates/status/889665388...
# 13      https://twitter.com/dog_rates/status/889638837...
# 14      https://twitter.com/dog_rates/status/889531135...
# 15      https://twitter.com/dog_rates/status/889278841...
# ...

# %% [markdown]
# ### #Issue 5

# %% [markdown]
# #### Define:
# Missing variable values in the tweet-json dataset including:
#  - contributors
#  - coordinates
#  - extended_entities
#  - geo
#  - in_reply_to_screen_name
#  - in_reply_to_status_id
#  - in_reply_to_status_id_str
#  - in_reply_to_user_id
#  - in_reply_to_user_id_str
#  - place
#  - possibly_sensitive
#  - possibly_sensitive_appealable
#  - quoted_status
#  - quoted_status_id
#  - quoted_status_id_str
#  - retweeted_status

# %% [markdown]
# #### Clean

# %%
tweets_clean.contributors.dropna(inplace = True)
tweets_clean.coordinates.dropna(inplace = True)
tweets_clean['extended_entities'].dropna(inplace = True)
tweets_clean.geo.dropna(inplace = True)
tweets_clean['in_reply_to_screen_name'].dropna(inplace = True)
tweets_clean['in_reply_to_status_id'].dropna(inplace = True)
tweets_clean['in_reply_to_status_id_str'].dropna(inplace = True)
tweets_clean['in_reply_to_user_id'].dropna(inplace = True)
tweets_clean['in_reply_to_user_id_str'].dropna(inplace = True)
tweets_clean.place.dropna(inplace = True)
tweets_clean['possibly_sensitive'].dropna(inplace = True)
tweets_clean['possibly_sensitive_appealable'].dropna(inplace = True)
tweets_clean['quoted_status'].dropna(inplace = True)
tweets_clean['quoted_status_id'].dropna(inplace = True)
tweets_clean['quoted_status_id_str'].dropna(inplace = True)
tweets_clean['retweeted_status'].dropna(inplace = True)

# %% [markdown]
# #### Test

# %%
tweets_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
# contributors                     0 non-null float64
# coordinates                      0 non-null float64
# created_at                       2354 non-null datetime64[ns]
# display_text_range               2354 non-null object
# entities                         2354 non-null object
# extended_entities                2073 non-null object
# favorite_count                   2354 non-null int64
# favorited                        2354 non-null bool
# full_text                        2354 non-null object
# geo                              0 non-null float64
# id                               2354 non-null int64
# id_str                           2354 non-null int64
# in_reply_to_screen_name          78 non-null object
# in_reply_to_status_id            78 non-null float64
# in_reply_to_status_id_str        78 non-null float64
# ...

# %% [markdown]
# ### #Issue 6
#
# #### Define:
# Getting rid of contributors, coordinates and geo columns in the tweet-json dataset as they are empty.

# %% [markdown]
# #### Clean

# %%
tweets_clean.drop(['contributors', 'coordinates', 'geo'], axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
tweets_clean.columns
# Out:
# Index(['created_at', 'display_text_range', 'entities', 'extended_entities',
#        'favorite_count', 'favorited', 'full_text', 'id', 'id_str',
#        'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'place',
#        'possibly_sensitive', 'possibly_sensitive_appealable', 'quoted_status',
#        'quoted_status_id', 'quoted_status_id_str', 'retweet_count',
#        'retweeted', 'retweeted_status', 'source', 'truncated', 'user'],
#       dtype='object')

# %% [markdown]
# ### #Issue 7

# %% [markdown]
# #### Define:
# p1, p2, and p3 in the Image predictions dataset do not have consistent letter format to give the names of dogs i.e. some dog names have capitalised first letters while others do not.

# %% [markdown]
# #### Clean

# %%
predictions_clean.columns
# Out:
# Index(['tweet_id', 'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2',
#        'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog'],
#       dtype='object')

# %%
predictions_clean['p1'] = predictions_clean['p1'].str.lower()
predictions_clean['p2'] = predictions_clean['p2'].str.lower()
predictions_clean['p3'] = predictions_clean['p3'].str.lower()

# %% [markdown]
# #### Test

# %%
predictions_clean['p1']
# Out:
# 0            welsh_springer_spaniel
# 1                           redbone
# 2                   german_shepherd
# 3               rhodesian_ridgeback
# 4                miniature_pinscher
# 5              bernese_mountain_dog
# 6                        box_turtle
# 7                              chow
# 8                     shopping_cart
# 9                  miniature_poodle
# 10                 golden_retriever
# 11                    gordon_setter
# 12                     walker_hound
# 13                              pug
# 14                       bloodhound
# 15                            lhasa
# 16                   english_setter
# 17                              hen
# 18                 desktop_computer
# 19                italian_greyhound
# 20                      maltese_dog
# 21                 three-toed_sloth
# 22                               ox
# 23                 golden_retriever
# 24                         malamute
# 25                       guinea_pig
# ...

# %%
predictions_clean['p2']
# Out:
# 0                         collie
# 1             miniature_pinscher
# 2                       malinois
# 3                        redbone
# 4                     rottweiler
# 5               english_springer
# 6                     mud_turtle
# 7                tibetan_mastiff
# 8                shopping_basket
# 9                       komondor
# 10               tibetan_mastiff
# 11             yorkshire_terrier
# 12              english_foxhound
# 13                  bull_mastiff
# 14               german_shepherd
# 15                      shih-tzu
# 16                  newfoundland
# 17                          cock
# 18                          desk
# 19                   toy_terrier
# 20                    toy_poodle
# 21                         otter
# 22                  newfoundland
# 23      chesapeake_bay_retriever
# 24                siberian_husky
# 25                         skunk
# 26                  afghan_hound
# 27                   toy_terrier
# ...

# %%
predictions_clean['p3']
# Out:
# 0                 shetland_sheepdog
# 1               rhodesian_ridgeback
# 2                        bloodhound
# 3                miniature_pinscher
# 4                          doberman
# 5        greater_swiss_mountain_dog
# 6                          terrapin
# 7                          fur_coat
# 8                  golden_retriever
# 9       soft-coated_wheaten_terrier
# 10               labrador_retriever
# 11                         pekinese
# 12                     ibizan_hound
# 13                   french_bulldog
# 14                         malinois
# 15                   dandie_dinmont
# 16                           borzoi
# 17                        partridge
# 18                         bookcase
# 19                          basenji
# 20                 miniature_poodle
# 21                   great_grey_owl
# 22                      groenendael
# 23               labrador_retriever
# 24                       eskimo_dog
# 25                          hamster
# ...

# %% [markdown]
# ### #Issue 8

# %% [markdown]
# #### Define:
# There exist images in the image predictions dataset that are not dogs. We would need to get rid of these as we are only interested in images of dogs.

# %% [markdown]
# #### Clean

# %%
predictions_clean[predictions_clean['p1_dog']==False]
# Out:
#                 tweet_id                                            jpg_url  \
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 17    666104133288665088    https://pbs.twimg.com/media/CT56LSZWoAAlJj2.jpg
# 18    666268910803644416    https://pbs.twimg.com/media/CT8QCd1WEAADXws.jpg
# 21    666293911632134144    https://pbs.twimg.com/media/CT8mx7KW4AEQu8N.jpg
# 22    666337882303524864    https://pbs.twimg.com/media/CT9OwFIWEAMuRje.jpg
# 25    666362758909284353    https://pbs.twimg.com/media/CT9lXGsUcAAyUFt.jpg
# 29    666411507551481857    https://pbs.twimg.com/media/CT-RugiWIAELEaq.jpg
# 33    666430724426358785    https://pbs.twimg.com/media/CT-jNYqW4AAPi2M.jpg
# 43    666776908487630848    https://pbs.twimg.com/media/CUDeDoWUYAAD-EM.jpg
# 45    666786068205871104    https://pbs.twimg.com/media/CUDmZIkWcAAIPPe.jpg
# ...

# %%
#predictions_clean.drop(predictions_clean[predictions_clean['p1_dog'] == False].index, inplace = True)
predictions_clean = predictions_clean[ (predictions_clean['p1_dog'] == True) | (predictions_clean['p2_dog'] == True) | (predictions_clean['p3_dog'] == True)]

# %% [markdown]
# #### Test

# %%
predictions_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1751 entries, 0 to 2073
# Data columns (total 12 columns):
# tweet_id    1751 non-null int64
# jpg_url     1751 non-null object
# img_num     1751 non-null int64
# p1          1751 non-null object
# p1_conf     1751 non-null float64
# p1_dog      1751 non-null bool
# p2          1751 non-null object
# p2_conf     1751 non-null float64
# p2_dog      1751 non-null bool
# p3          1751 non-null object
# p3_conf     1751 non-null float64
# p3_dog      1751 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 141.9+ KB

# %%
predictions_clean[(predictions_clean['p1_dog']==False) & (predictions_clean['p2_dog']==False) & (predictions_clean['p3_dog']==False)]
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []

# %% [markdown]
# ### #Issue 9

# %% [markdown]
# #### Define:
# Changing the column name in the twitter_archive dataframe for consistency with the tweet_json dataframe. This is important for the next issue in the data cleaning process.

# %% [markdown]
# #### Clean

# %%
twitter_archive_clean.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %%
tweets_clean.columns
# Out:
# Index(['created_at', 'display_text_range', 'entities', 'extended_entities',
#        'favorite_count', 'favorited', 'full_text', 'id', 'id_str',
#        'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'place',
#        'possibly_sensitive', 'possibly_sensitive_appealable', 'quoted_status',
#        'quoted_status_id', 'quoted_status_id_str', 'retweet_count',
#        'retweeted', 'retweeted_status', 'source', 'truncated', 'user'],
#       dtype='object')

# %%
twitter_archive_clean.rename(columns = {'tweet_id':'id'}, inplace = True)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.columns
# Out:
# Index(['id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %% [markdown]
# ### #Issue 10

# %% [markdown]
# There is no need for 2 different datasets(tweet-json file and the twitter archive file). The two can be merged.

# %% [markdown]
# #### Clean

# %%
tweets_clean['id'] = tweets_clean['id'].astype('category')
twitter_archive_combined = pd.merge(twitter_archive_clean, tweets_clean,
                                on=['id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'source'], how='left')

# %% [markdown]
# #### Test

# %%
twitter_archive_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2174
# Data columns (total 41 columns):
# id                               2175 non-null int64
# in_reply_to_status_id            78 non-null float64
# in_reply_to_user_id              78 non-null float64
# timestamp                        2175 non-null datetime64[ns]
# source                           2175 non-null object
# text                             2175 non-null object
# retweeted_status_id              0 non-null float64
# retweeted_status_user_id         0 non-null float64
# retweeted_status_timestamp       0 non-null object
# expanded_urls                    2117 non-null object
# rating_numerator                 2175 non-null float64
# rating_denominator               2175 non-null float64
# name                             2175 non-null object
# doggo                            2175 non-null object
# floofer                          2175 non-null object
# ...

# %% [markdown]
# ### #Issue 11

# %% [markdown]
# #### Define:
# floofer, puppo, and doggo columns that denote the stage in which the dog is in are mutually exclusive except when a mistake occurs. They should therefore be in a single column

# %% [markdown]
# #### Clean

# %%
twitter_archive_combined.columns
# Out:
# Index(['id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo',
#        'created_at', 'display_text_range', 'entities', 'extended_entities',
#        'favorite_count', 'favorited', 'full_text', 'id_str',
#        'in_reply_to_screen_name', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'place',
#        'possibly_sensitive', 'possibly_sensitive_appealable', 'quoted_status',
#        'quoted_status_id', 'quoted_status_id_str', 'retweet_count',
#        'retweeted', 'retweeted_status', 'truncated', 'user'],
#       dtype='object')

# %%
# replace None values with blanks
#for stage in ['doggo', 'floofer', 'pupper', 'puppo']:
# twitter_archive_combined[stage].replace('None', '', inplace = True)
#twitter_archive_combined = pd.melt(twitter_archive_combined, id_vars=['id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#       'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#       'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#       'rating_denominator', 'name',
#       'created_at', 'display_text_range', 'entities', 'extended_entities',
#       'favorite_count', 'favorited', 'full_text', 'id_str',
#       'in_reply_to_screen_name', 'in_reply_to_status_id_str',
#       'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'place',
#       'possibly_sensitive', 'possibly_sensitive_appealable', 'quoted_status',
#       'quoted_status_id', 'quoted_status_id_str', 'retweet_count',
#       'retweeted', 'retweeted_status', 'truncated', 'user'], value_vars= ['doggo', 'floofer', 'pupper', 'puppo'], var_name='dog_stage', value_name='stage').drop('dog_stage', 1)

# %%
# replace None values with blanks
#for stage in ['doggo', 'floofer', 'pupper', 'puppo']:
 #twitter_archive_combined[stage].replace('None', '', inplace = True)
#twitter_archive_combined['stage'] = twitter_archive_clean['floofer'] + twitter_archive_clean['puppo'] + twitter_archive_clean['doggo'] +twitter_archive_clean['pupper']

# %%
# replacing None values
twitter_archive_combined.doggo.replace('None', '', inplace = True)
twitter_archive_combined.floofer.replace('None', '', inplace = True)
twitter_archive_combined.pupper.replace('None', '', inplace = True)
twitter_archive_combined.puppo.replace('None', '', inplace = True)

#combining the stage columns
twitter_archive_combined['stage'] = twitter_archive_combined.doggo + twitter_archive_combined.floofer + twitter_archive_combined.pupper + twitter_archive_combined.puppo

# format entries
twitter_archive_combined.loc[twitter_archive_combined.stage == 'doggopupper', 'stage'] = 'doggo, pupper'
twitter_archive_combined.loc[twitter_archive_combined.stage == 'doggopuppo', 'stage'] = 'doggo, puppo'
twitter_archive_combined.loc[twitter_archive_combined.stage == 'doggofloofer', 'stage'] = 'doggo, floofer'
twitter_archive_combined.loc[twitter_archive_combined.stage == 'doggoflooferpupperpuppo', 'stage'] = 'doggo, floofer, pupper, puppo'
twitter_archive_combined.loc[twitter_archive_combined.stage == 'doggopupperpuppo', 'stage'] = 'doggo, pupper, puppo'

# %%
twitter_archive_combined.stage.value_counts()
# Out:
#                   1831
# pupper             224
# doggo               75
# puppo               24
# doggo, pupper       10
# floofer              9
# doggo, puppo         1
# doggo, floofer       1
# Name: stage, dtype: int64

# %% [markdown]
# #### Test

# %%
twitter_archive_combined.head()
# Out:
#                    id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#             timestamp                                             source  \
# 0 2017-08-01 16:23:56  <a href="http://twitter.com/download/iphone" r...
# 1 2017-08-01 00:17:27  <a href="http://twitter.com/download/iphone" r...
# 2 2017-07-31 00:18:03  <a href="http://twitter.com/download/iphone" r...
# 3 2017-07-30 15:58:51  <a href="http://twitter.com/download/iphone" r...
# 4 2017-07-29 16:00:24  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# ...

# %%
twitter_archive_combined
# Out:
#                       id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %% [markdown]
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
predictions_clean.rename(columns = {'tweet_id':'id'}, inplace = True)
predictions_clean.columns
# Out:
# Index(['id', 'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2', 'p2_conf',
#        'p2_dog', 'p3', 'p3_conf', 'p3_dog'],
#       dtype='object')

# %%
predictions_clean['id'].dtype
# Out:
# dtype('int64')

# %%
twitter_archive_combined.columns
# Out:
# Index(['id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo',
#        'created_at', 'display_text_range', 'entities', 'extended_entities',
#        'favorite_count', 'favorited', 'full_text', 'id_str',
#        'in_reply_to_screen_name', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'place',
#        'possibly_sensitive', 'possibly_sensitive_appealable', 'quoted_status',
#        'quoted_status_id', 'quoted_status_id_str', 'retweet_count',
#        'retweeted', 'retweeted_status', 'truncated', 'user', 'stage'],
#       dtype='object')

# %%
twitter_archive_combined['id'].dtype
# Out:
# dtype('int64')

# %%
#let us first merge the twitter_archive_combined dataset with the predictions dataset
twitter_archive_master = pd.merge(twitter_archive_combined, predictions_clean, on = 'id', how='left')

# %%
twitter_archive_master.columns
# Out:
# Index(['id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo',
#        'created_at', 'display_text_range', 'entities', 'extended_entities',
#        'favorite_count', 'favorited', 'full_text', 'id_str',
#        'in_reply_to_screen_name', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'place',
#        'possibly_sensitive', 'possibly_sensitive_appealable', 'quoted_status',
#        'quoted_status_id', 'quoted_status_id_str', 'retweet_count',
#        'retweeted', 'retweeted_status', 'truncated', 'user', 'stage',
#        'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2', 'p2_conf',
#        'p2_dog', 'p3', 'p3_conf', 'p3_dog'],
#       dtype='object')

# %%
twitter_archive_master.to_csv('twitter_archive_master.csv')

# %% [markdown]
# ## Analyzing and Visualizing Data
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %%
twitter_archive_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2174
# Data columns (total 53 columns):
# id                               2175 non-null int64
# in_reply_to_status_id            78 non-null float64
# in_reply_to_user_id              78 non-null float64
# timestamp                        2175 non-null datetime64[ns]
# source                           2175 non-null object
# text                             2175 non-null object
# retweeted_status_id              0 non-null float64
# retweeted_status_user_id         0 non-null float64
# retweeted_status_timestamp       0 non-null object
# expanded_urls                    2117 non-null object
# rating_numerator                 2175 non-null float64
# rating_denominator               2175 non-null float64
# name                             2175 non-null object
# doggo                            2175 non-null object
# floofer                          2175 non-null object
# ...

# %%
twitter_archive_master.describe()
# Out:
#                  id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.175000e+03           7.800000e+01         7.800000e+01
# mean   7.371205e+17           7.455079e+17         2.014171e+16
# std    6.748668e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.768432e+17           6.757419e+17         3.086374e+08
# 50%    7.098528e+17           7.038708e+17         4.196984e+09
# 75%    7.894226e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count                  0.0                       0.0       2175.000000
# mean                   NaN                       NaN         13.215172
# std                    NaN                       NaN         47.725696
# min                    NaN                       NaN          0.000000
# ...

# %% [markdown]
# ### Questions that need answers
# - What was the highest rating given?
# - Who received the most retweets?
# - What dog breed was submitted the most to We Rate Dogs twitter account for rating?

# %%
twitter_archive_master['rating_numerator'].max()
# Out:
# 1776.0

# %%
twitter_archive_master[twitter_archive_master['rating_numerator']==1776]
# Out:
#                      id  in_reply_to_status_id  in_reply_to_user_id  \
# 804  749981277374128128                    NaN                  NaN
#
#               timestamp                                             source  \
# 804 2016-07-04 15:00:45  <a href="https://about.twitter.com/products/tw...
#
#                                                   text  retweeted_status_id  \
# 804  This is Atticus. He's quite simply America af....                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 804                       NaN                        NaN
#
#                                          expanded_urls  ...    img_num   p1  \
# 804  https://twitter.com/dog_rates/status/749981277...  ...        NaN  NaN
#
#     p1_conf p1_dog   p2 p2_conf p2_dog   p3 p3_conf p3_dog
# 804     NaN    NaN  NaN     NaN    NaN  NaN     NaN    NaN
#
# [1 rows x 53 columns]

# %%
twitter_archive_master['retweet_count'].describe()
# Out:
# count     2175.000000
# mean      2757.987126
# std       4646.599662
# min          0.000000
# 25%        608.000000
# 50%       1341.000000
# 75%       3220.000000
# max      79515.000000
# Name: retweet_count, dtype: float64

# %%
twitter_archive_master[twitter_archive_master['retweet_count'] == 79515]
# Out:
#                      id  in_reply_to_status_id  in_reply_to_user_id  \
# 862  744234799360020481                    NaN                  NaN
#
#               timestamp                                             source  \
# 862 2016-06-18 18:26:18  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 862  Here's a doggo realizing you can stand in a po...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 862                       NaN                        NaN
#
#                                          expanded_urls  ...    img_num  \
# 862  https://twitter.com/dog_rates/status/744234799...  ...        1.0
#
#                      p1   p1_conf p1_dog        p2   p2_conf p2_dog       p3  \
# 862  labrador_retriever  0.825333   True  ice_bear  0.044681  False  whippet
#
#       p3_conf p3_dog
# 862  0.018442   True
#
# [1 rows x 53 columns]

# %%
twitter_archive_master['p1'].value_counts()
# Out:
# golden_retriever               139
# labrador_retriever              95
# pembroke                        88
# chihuahua                       79
# pug                             54
# chow                            41
# samoyed                         40
# pomeranian                      38
# toy_poodle                      38
# malamute                        29
# cocker_spaniel                  27
# french_bulldog                  26
# chesapeake_bay_retriever        23
# miniature_pinscher              22
# seat_belt                       20
# siberian_husky                  20
# german_shepherd                 20
# staffordshire_bullterrier       19
# maltese_dog                     18
# shetland_sheepdog               18
# eskimo_dog                      18
# beagle                          17
# cardigan                        17
# shih-tzu                        17
# rottweiler                      17
# italian_greyhound               16
# lakeland_terrier                16
# ...

# %%
twitter_archive_master['p2'].value_counts()
# Out:
# labrador_retriever                96
# golden_retriever                  82
# cardigan                          72
# chihuahua                         43
# chesapeake_bay_retriever          40
# pomeranian                        39
# french_bulldog                    39
# toy_poodle                        36
# siberian_husky                    33
# cocker_spaniel                    32
# miniature_poodle                  32
# beagle                            28
# eskimo_dog                        27
# collie                            26
# pembroke                          25
# kuvasz                            24
# italian_greyhound                 22
# pekinese                          21
# american_staffordshire_terrier    20
# miniature_pinscher                20
# malinois                          20
# chow                              20
# samoyed                           19
# boston_bull                       19
# norwegian_elkhound                19
# ...

# %% [markdown]
# ### Insights:
# 1. The highest rating ever given to a single dog was 1776. A quick twitter search reveals that it was given to Atticus, a dog sitting in front of the American flag. The reason for such a high rating then becomes clear(1776 was America's year of independence).
#
# 2. At a staggering retweet count of 79515, the 13/10 rated doggo who received this was quite adorably standing in a pool.
#
# 3. Golden retrievers were the most submitted dog breeds to the We Rate Dogs twitter account for rating.

# %% [markdown]
# ### Visualization

# %% [markdown]
# Let us find out whether or not retweet counts and favourite counts are correlated.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#breeds = twitter_archive_master.groupby(['p1']).mean()

# %%
#breeds.sample(10)
# Out:
#                             id  in_reply_to_status_id  in_reply_to_user_id  \
# p1
# car_mirror        7.270110e+17                    NaN                  NaN
# seat_belt         7.274350e+17                    NaN                  NaN
# pug               7.157859e+17                    NaN                  NaN
# chihuahua         7.237484e+17           6.844811e+17         4.196984e+09
# hay               6.669961e+17                    NaN                  NaN
# lhasa             6.938866e+17                    NaN                  NaN
# cup               7.363659e+17                    NaN                  NaN
# mexican_hairless  7.703900e+17                    NaN                  NaN
# king_penguin      6.682973e+17                    NaN                  NaN
# handkerchief      7.280353e+17                    NaN                  NaN
#
#                   retweeted_status_id  retweeted_status_user_id  \
# p1
# car_mirror                        NaN                       NaN
# ...

# %%
#fig = plt.figure(figsize = (20, 20))
#breeds.plot.bar
#plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#breeds['retweet_count'].plot()

# %%
#twitter_archive_master.groupby(['p1'])['retweet_count'].mean().plot(legend=True)

# %%
#retrievers = twitter_archive_master['p1'] == 'golden_retriever'

# %%
twitter_archive_master.plot.scatter('retweet_count', 'favorite_count')
plt.title('Scatter Plot of retweet count and favourite count')
# Out:
# Text(0.5,1,'Scatter Plot of retweet count and favourite count')
